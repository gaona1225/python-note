# %%
# 一、Pandas 提供了两种用于处理数据的类
#     1、Series：一个一维的带标签数组，可容纳任何类型的数据，例如整数、字符串、Python 对象等。
#     2、DataFrame：一个二维数据结构，像二维数组或带有行和列的表格一样容纳数据。
import numpy as np
import pandas as pd

# %%
# 通过传入值列表创建Series，让 pandas 创建默认的RangeIndex。
# np.nan 表示NaN
series_test = pd.Series([1, 3, 5, np.nan, 6, 8])
series_test
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# 通过传入 NumPy 数组，使用date_range()创建带有日期时间索引和标签列的DataFrame
date_test = pd.date_range('20251203', periods = 6)
date_test
# Out:
# DatetimeIndex(['2025-12-03', '2025-12-04', '2025-12-05', '2025-12-06',
#                '2025-12-07', '2025-12-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
# np.random.randn(6, 4) 会生成一个形状为 6×4 的二维 NumPy 数组，也可以理解为 6 行 4 列的“矩阵”
# 里面的 24 个元素都是浮点数，每个元素都是从“标准正态分布”（均值 0、方差 1 的高斯分布）中随机采样得到的随机数。
date_test2 = pd.DataFrame(np.random.randn(6, 4), index = date_test, columns = list('ABCD'))
date_test2
# Out:
#                    A         B         C         D
# 2025-12-03 -1.243476  0.096030 -0.260659 -1.659298
# 2025-12-04 -0.936297 -0.287746 -1.108223 -0.309034
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440
# 2025-12-06  0.258543  0.434482 -0.033379  1.803157
# 2025-12-07 -1.012616 -2.292247 -0.314333  0.544293
# 2025-12-08  0.882174 -1.389833  0.878938  1.590671

# %%
# 通过传入一个对象字典创建DataFrame，其中键是列标签，值是列值。
dataFrame_test = pd.DataFrame({
    'A': 1.0,
    'B': pd.Timestamp('20251203'),
    'C': pd.Series(1, index = list(range(4)), dtype = 'float32'),
    'D': np.array([6] * 4, dtype = 'int32'),
    'E': pd.Categorical(['test1', 'train1', 'test2', 'train2']),
    'F': 'foo',
    'G': True
})
print(dataFrame_test)
print(dataFrame_test.dtypes)
# Out:
#      A          B    C  D       E    F     G
# 0  1.0 2025-12-03  1.0  6   test1  foo  True
# 1  1.0 2025-12-03  1.0  6  train1  foo  True
# 2  1.0 2025-12-03  1.0  6   test2  foo  True
# 3  1.0 2025-12-03  1.0  6  train2  foo  True
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# G             bool
# dtype: object

# %%
# 使用DataFrame.head()和DataFrame.tail()分别查看框架的顶部和底部行。
print(dataFrame_test.head(2))
print(dataFrame_test.tail(1))
# 显示DataFrame.index或DataFrame.columns
print('indexs are:', dataFrame_test.index)
print('columns are:', dataFrame_test.columns)
# Out:
#      A          B    C  D       E    F     G
# 0  1.0 2025-12-03  1.0  6   test1  foo  True
# 1  1.0 2025-12-03  1.0  6  train1  foo  True
#      A          B    C  D       E    F     G
# 3  1.0 2025-12-03  1.0  6  train2  foo  True
# indexs are: Index([0, 1, 2, 3], dtype='int64')
# columns are: Index(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')

# %%
# 使用DataFrame.to_numpy()返回底层数据的 NumPy 表示，不包含索引或列标签。
print('date_test2 is: ', date_test2)
date_test2_to_np = date_test2.to_numpy()
print(date_test2_to_np)
# Out:
# date_test2 is:                     A         B         C         D
# 2025-12-03 -1.243476  0.096030 -0.260659 -1.659298
# 2025-12-04 -0.936297 -0.287746 -1.108223 -0.309034
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440
# 2025-12-06  0.258543  0.434482 -0.033379  1.803157
# 2025-12-07 -1.012616 -2.292247 -0.314333  0.544293
# 2025-12-08  0.882174 -1.389833  0.878938  1.590671
# [[-1.24347629  0.09603044 -0.26065926 -1.65929816]
#  [-0.9362971  -0.28774645 -1.10822292 -0.30903369]
#  [ 0.07566872 -1.49367198  1.10595714  1.96843973]
#  [ 0.25854285  0.43448182 -0.03337938  1.80315722]
#  [-1.01261612 -2.2922469  -0.31433259  0.54429308]
#  [ 0.88217432 -1.3898331   0.87893808  1.59067119]]

# %%
# NumPy 数组的整个数组只有一个 dtype，而 pandas DataFrames 的每列有一个 dtype
print(dataFrame_test['D'].dtypes)
print(dataFrame_test.dtypes)
# Out:
# int32
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# G             bool
# dtype: object

# %%
print(dataFrame_test)
print(dataFrame_test.describe())
# Out:
#      A          B    C  D       E    F     G
# 0  1.0 2025-12-03  1.0  6   test1  foo  True
# 1  1.0 2025-12-03  1.0  6  train1  foo  True
# 2  1.0 2025-12-03  1.0  6   test2  foo  True
# 3  1.0 2025-12-03  1.0  6  train2  foo  True
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2025-12-03 00:00:00  1.0  6.0
# min    1.0  2025-12-03 00:00:00  1.0  6.0
# 25%    1.0  2025-12-03 00:00:00  1.0  6.0
# 50%    1.0  2025-12-03 00:00:00  1.0  6.0
# 75%    1.0  2025-12-03 00:00:00  1.0  6.0
# max    1.0  2025-12-03 00:00:00  1.0  6.0
# std    0.0                  NaN  0.0  0.0

# %%
# 转置数据
print(dataFrame_test.T)
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2025-12-03 00:00:00  2025-12-03 00:00:00  2025-12-03 00:00:00
# C                  1.0                  1.0                  1.0
# D                    6                    6                    6
# E                test1               train1                test2
# F                  foo                  foo                  foo
# G                 True                 True                 True
#
#                      3
# A                  1.0
# B  2025-12-03 00:00:00
# C                  1.0
# D                    6
# E               train2
# F                  foo
# G                 True

# %%
# DataFrame.sort_index()按轴排序
print(date_test2.sort_index(axis = 0, ascending = False))
print(date_test2.sort_values(by = 'A'))
print('source...', date_test2)
# Out:
#                    A         B         C         D
# 2025-12-08  0.882174 -1.389833  0.878938  1.590671
# 2025-12-07 -1.012616 -2.292247 -0.314333  0.544293
# 2025-12-06  0.258543  0.434482 -0.033379  1.803157
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440
# 2025-12-04 -0.936297 -0.287746 -1.108223 -0.309034
# 2025-12-03 -1.243476  0.096030 -0.260659 -1.659298
#                    A         B         C         D
# 2025-12-03 -1.243476  0.096030 -0.260659 -1.659298
# 2025-12-07 -1.012616 -2.292247 -0.314333  0.544293
# 2025-12-04 -0.936297 -0.287746 -1.108223 -0.309034
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440
# 2025-12-06  0.258543  0.434482 -0.033379  1.803157
# 2025-12-08  0.882174 -1.389833  0.878938  1.590671
# source...                    A         B         C         D
# 2025-12-03 -1.243476  0.096030 -0.260659 -1.659298
# 2025-12-04 -0.936297 -0.287746 -1.108223 -0.309034
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440
# 2025-12-06  0.258543  0.434482 -0.033379  1.803157
# 2025-12-07 -1.012616 -2.292247 -0.314333  0.544293
# 2025-12-08  0.882174 -1.389833  0.878938  1.590671

# %%
# .loc 主要基于标签，但也可与布尔数组一起使用
print(date_test2.loc[:, 'A'])
print(date_test2.at['2025-12-05', 'B'])
# .iloc 主要基于整数位置（从轴的 0 到 length-1）
print(date_test2.iloc[:, 1])
# Out:
# 2025-12-03   -1.243476
# 2025-12-04   -0.936297
# 2025-12-05    0.075669
# 2025-12-06    0.258543
# 2025-12-07   -1.012616
# 2025-12-08    0.882174
# Freq: D, Name: A, dtype: float64
# -1.4936719830133607
# 2025-12-03    0.096030
# 2025-12-04   -0.287746
# 2025-12-05   -1.493672
# 2025-12-06    0.434482
# 2025-12-07   -2.292247
# 2025-12-08   -1.389833
# Freq: D, Name: B, dtype: float64

# %%
print(dataFrame_test)
print(dataFrame_test['E'])
print(dataFrame_test.E)
# Out:
#      A          B    C  D       E    F     G
# 0  1.0 2025-12-03  1.0  6   test1  foo  True
# 1  1.0 2025-12-03  1.0  6  train1  foo  True
# 2  1.0 2025-12-03  1.0  6   test2  foo  True
# 3  1.0 2025-12-03  1.0  6  train2  foo  True
# 0     test1
# 1    train1
# 2     test2
# 3    train2
# Name: E, dtype: category
# Categories (4, object): ['test1', 'test2', 'train1', 'train2']
# 0     test1
# 1    train1
# 2     test2
# 3    train2
# Name: E, dtype: category
# Categories (4, object): ['test1', 'test2', 'train1', 'train2']

# %%
# 对于DataFrame，传入切片 : 会选择匹配的行。
# print(dataFrame_test[0:2])
print(date_test2['2025-12-03':'2025-12-05'])
# Out:
#                    A         B         C         D
# 2025-12-03 -1.243476  0.096030 -0.260659 -1.659298
# 2025-12-04 -0.936297 -0.287746 -1.108223 -0.309034
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440

# %%
# 选择所有行 (:) 和选定的列标签
print(date_test2)
print(date_test2.loc[:, ['A', 'B']])
print('date_test is:', date_test)
print(date_test2.loc[date_test[1], 'A'])
# Out:
#                    A         B         C         D
# 2025-12-03 -1.243476  0.096030 -0.260659 -1.659298
# 2025-12-04 -0.936297 -0.287746 -1.108223 -0.309034
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440
# 2025-12-06  0.258543  0.434482 -0.033379  1.803157
# 2025-12-07 -1.012616 -2.292247 -0.314333  0.544293
# 2025-12-08  0.882174 -1.389833  0.878938  1.590671
#                    A         B
# 2025-12-03 -1.243476  0.096030
# 2025-12-04 -0.936297 -0.287746
# 2025-12-05  0.075669 -1.493672
# 2025-12-06  0.258543  0.434482
# 2025-12-07 -1.012616 -2.292247
# 2025-12-08  0.882174 -1.389833
# date_test is: DatetimeIndex(['2025-12-03', '2025-12-04', '2025-12-05', '2025-12-06',
#                '2025-12-07', '2025-12-08'],
#               dtype='datetime64[ns]', freq='D')
# -0.9362970988655746

# %%
print(date_test2.iloc[1])
print(date_test2.iloc[1, 1])
print(date_test2.iat[1, 1])
print(date_test2[date_test2['A'] > 0])
# Out:
# A   -0.936297
# B   -0.287746
# C   -1.108223
# D   -0.309034
# Name: 2025-12-04 00:00:00, dtype: float64
# -0.28774645016955397
# -0.28774645016955397
#                    A         B         C         D
# 2025-12-05  0.075669 -1.493672  1.105957  1.968440
# 2025-12-06  0.258543  0.434482 -0.033379  1.803157
# 2025-12-08  0.882174 -1.389833  0.878938  1.590671

# %%
# 使用isin()方法进行过滤
print(dataFrame_test)
dataFrame_test2 = dataFrame_test.copy()
dataFrame_test2['H'] = ["one", "one", "two", "three"]
print(dataFrame_test2)
print(dataFrame_test2[dataFrame_test2['H'].isin(['one', 'three'])])
# Out:
#      A          B    C  D       E    F     G
# 0  1.0 2025-12-03  1.0  6   test1  foo  True
# 1  1.0 2025-12-03  1.0  6  train1  foo  True
# 2  1.0 2025-12-03  1.0  6   test2  foo  True
# 3  1.0 2025-12-03  1.0  6  train2  foo  True
#      A          B    C  D       E    F     G      H
# 0  1.0 2025-12-03  1.0  6   test1  foo  True    one
# 1  1.0 2025-12-03  1.0  6  train1  foo  True    one
# 2  1.0 2025-12-03  1.0  6   test2  foo  True    two
# 3  1.0 2025-12-03  1.0  6  train2  foo  True  three
#      A          B    C  D       E    F     G      H
# 0  1.0 2025-12-03  1.0  6   test1  foo  True    one
# 1  1.0 2025-12-03  1.0  6  train1  foo  True    one
# 3  1.0 2025-12-03  1.0  6  train2  foo  True  three

# %%
dataFrame_test2.at['2025-12-03', 'D'] = 12
print(dataFrame_test2)
# Out:
#               A          B    C     D       E    F     G      H
# 0           1.0 2025-12-03  1.0   6.0   test1  foo  True    one
# 1           1.0 2025-12-03  1.0   6.0  train1  foo  True    one
# 2           1.0 2025-12-03  1.0   6.0   test2  foo  True    two
# 3           1.0 2025-12-03  1.0   6.0  train2  foo  True  three
# 2025-12-03  NaN        NaT  NaN  12.0     NaN  NaN   NaN    NaN

# %%
# DataFrame.dropna()删除任何包含缺失数据的行,缺失数据是值NaN
dataFrame_test2_nan = dataFrame_test2.dropna(how = 'any')
print(dataFrame_test2_nan)
# Out:
#      A          B    C    D       E    F     G      H
# 0  1.0 2025-12-03  1.0  6.0   test1  foo  True    one
# 1  1.0 2025-12-03  1.0  6.0  train1  foo  True    one
# 2  1.0 2025-12-03  1.0  6.0   test2  foo  True    two
# 3  1.0 2025-12-03  1.0  6.0  train2  foo  True  three

# %%
print(dataFrame_test2)
# Out:
#               A          B    C     D       E    F     G      H
# 0           1.0 2025-12-03  1.0   6.0   test1  foo  True    one
# 1           1.0 2025-12-03  1.0   6.0  train1  foo  True    one
# 2           1.0 2025-12-03  1.0   6.0   test2  foo  True    two
# 3           1.0 2025-12-03  1.0   6.0  train2  foo  True  three
# 2025-12-03  NaN        NaT  NaN  12.0     NaN  NaN   NaN    NaN

# %%
# DataFrame.fillna()填充缺失数据
df = pd.DataFrame({
    'A': [1, np.nan, 3],
    'B': [np.nan, 5, np.nan]
})
print(df)
df_fillna = df.fillna(value = 6)
print('again:', df)
print(df_fillna)
# isna()获取值为 nan 的布尔掩码
print(df.isna())
print(pd.isna(df))
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  5.0
# 2  3.0  NaN
# again:      A    B
# 0  1.0  NaN
# 1  NaN  5.0
# 2  3.0  NaN
#      A    B
# 0  1.0  6.0
# 1  6.0  5.0
# 2  3.0  6.0
#        A      B
# 0  False   True
# 1   True  False
# 2  False   True
#        A      B
# 0  False   True
# 1   True  False
# 2  False   True

# %%
# DataFrame.agg()和DataFrame.transform()分别应用一个用户定义函数，该函数会减少或广播其结果。
df_agg_multiple6 = df_fillna.agg(lambda x: np.mean(x) * 6)
print('df_agg_multiple6:', df_agg_multiple6)
df_agg_multiple10 = df_fillna.transform(lambda x: x * 10)
print('df_agg_multiple10:', df_agg_multiple10)
# Out:
# df_agg_multiple6: A    20.0
# B    34.0
# dtype: float64
# df_agg_multiple10:       A     B
# 0  10.0  60.0
# 1  60.0  50.0
# 2  30.0  60.0

# %%
# 随机数size个0-8之间整数
s = pd.Series(np.random.randint(0, 8, size = 10))
print(s)
print(s.value_counts())
# Out:
# 0    6
# 1    1
# 2    6
# 3    2
# 4    2
# 5    7
# 6    0
# 7    1
# 8    1
# 9    6
# dtype: int64
# 6    3
# 1    3
# 2    2
# 7    1
# 0    1
# Name: count, dtype: int64

# %%
# merge() 基于唯一键进行合并
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
pd.merge(left, right, on = 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df_group = pd.DataFrame({
    'A': ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
    'B': ["one", "one", "two", "three", "two", "two", "one", "three"],
    'C': np.random.randn(8),
    'D': np.random.randn(8)
})
print(df_group)
# Out:
#      A      B         C         D
# 0  foo    one -0.028358  1.377010
# 1  bar    one  1.701011  0.392585
# 2  foo    two -1.266354  0.491844
# 3  bar  three  0.209163  0.834231
# 4  foo    two -0.456750 -1.909935
# 5  bar    two  2.838245  0.139970
# 6  foo    one -1.294614 -1.118750
# 7  foo  three  0.525427  1.497628

# %%
# 按列标签分组，选择列标签，然后将DataFrameGroupBy.sum()函数应用于结果组
df_group.groupby('A')[['C', 'D']].sum()
# Out:
#             C         D
# A
# bar  4.748420  1.366786
# foo -2.520649  0.337797

# %%
df_group
# Out:
#      A      B         C         D
# 0  foo    one -0.028358  1.377010
# 1  bar    one  1.701011  0.392585
# 2  foo    two -1.266354  0.491844
# 3  bar  three  0.209163  0.834231
# 4  foo    two -0.456750 -1.909935
# 5  bar    two  2.838245  0.139970
# 6  foo    one -1.294614 -1.118750
# 7  foo  three  0.525427  1.497628

# %%
# 按多列标签分组会形成MultiIndex。
df_group_multiIndex = df_group.groupby(['A', 'B']).sum()
df_group_multiIndex
# Out:
#                   C         D
# A   B
# bar one    1.701011  0.392585
#     three  0.209163  0.834231
#     two    2.838245  0.139970
# foo one   -1.322972  0.258260
#     three  0.525427  1.497628
#     two   -1.723104 -1.418091

# %%
# stack()方法“压缩”了 DataFrame 列中的一个层
stacked = df_group_multiIndex.stack(future_stack = True)
print(stacked)
# Out:
# A    B
# bar  one    C    1.701011
#             D    0.392585
#      three  C    0.209163
#             D    0.834231
#      two    C    2.838245
#             D    0.139970
# foo  one    C   -1.322972
#             D    0.258260
#      three  C    0.525427
#             D    1.497628
#      two    C   -1.723104
#             D   -1.418091
# dtype: float64

# %%
print(stacked.unstack())
# Out:
#                   C         D
# A   B
# bar one    1.701011  0.392585
#     three  0.209163  0.834231
#     two    2.838245  0.139970
# foo one   -1.322972  0.258260
#     three  0.525427  1.497628
#     two   -1.723104 -1.418091

# %%
stacked
# Out:
# A    B
# bar  one    C    1.701011
#             D    0.392585
#      three  C    0.209163
#             D    0.834231
#      two    C    2.838245
#             D    0.139970
# foo  one    C   -1.322972
#             D    0.258260
#      three  C    0.525427
#             D    1.497628
#      two    C   -1.723104
#             D   -1.418091
# dtype: float64

# %%
df_pivot = pd.DataFrame({
    'A': ['one', 'one', 'two', 'three'] * 3,
    'B': ['A', 'B', 'C'] * 4,
    'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
    'D': np.random.randn(12),
    'E': np.random.randn(12)
})
print(df_pivot)
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.867830 -0.811480
# 1     one  B  foo  0.266146  0.831526
# 2     two  C  foo  1.061925 -0.038419
# 3   three  A  bar  1.607607  0.301007
# 4     one  B  bar  1.065435  0.130957
# 5     one  C  bar -0.588279  0.749327
# 6     two  A  foo  0.368992  0.746474
# 7   three  B  foo  0.002015  0.217943
# 8     one  C  foo  0.162098  0.153572
# 9     one  A  bar -1.089910 -0.615987
# 10    two  B  bar -0.527178  1.755444
# 11  three  C  bar -1.210413  0.836324

# %%
# pivot_table()通过指定values、index和columns来透视DataFrame
pd.pivot_table(df_pivot, values = 'D', index = ['A', 'B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A -1.089910 -0.867830
#       B  1.065435  0.266146
#       C -0.588279  0.162098
# three A  1.607607       NaN
#       B       NaN  0.002015
#       C -1.210413       NaN
# two   A       NaN  0.368992
#       B -0.527178       NaN
#       C       NaN  1.061925

# %%
df_category = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'raw_grade': ['a', 'b', 'b', 'a', 'a', 'e']
})
print(df_category)
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df_category['grade'] = df_category['raw_grade'].astype('category')
print(df_category['grade'])
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ['very good', 'good', 'very bad']
df_category['grade'] = df_category['grade'].cat.rename_categories(new_categories)
print(df_category['grade'])
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'good', 'very bad']

# %%
import matplotlib.pyplot as plt
# plt.close 方法用于关闭图形窗口
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range('1/1/2000', periods = 1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df_plot = pd.DataFrame(np.random.randn(1000, 4), index = ts.index, columns = ['A', 'B', 'C', 'D'])
df_plot = df_plot.cumsum()
plt.figure()
df_plot.plot()
plt.legend(loc = 'best')

# %%
# 写入 CSV 文件：使用DataFrame.to_csv()
# 10行5列的0～5之间的整数
df_write = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
# df_write
df_write.to_csv('data/df_write.csv')

# %%
df_read = pd.read_csv('data/df_write.csv')
df_read.head()
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  1  4  2  4
# 1           1  0  0  1  3  3
# 2           2  0  4  1  0  4
# 3           3  0  2  0  3  3
# 4           4  1  1  2  3  4

# %%
# pip install parquet

# %%
# 写入 Excel 文件
df_write.to_excel('data/df_write.xlsx', sheet_name = 'Sheet1')

# %%
df_read_excel = pd.read_excel('data/df_write.xlsx')
df_read_excel.head()
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  1  4  2  4
# 1           1  0  0  1  3  3
# 2           2  0  4  1  0  4
# 3           3  0  2  0  3  3
# 4           4  1  1  2  3  4

# %%
# conda install -c conda-forge pyarrow

# %%
# 读写入 Parquet 文件, to_parquet() 需要 pyarrow 或 fastparquet 引擎支持，需要先安装
# df_write.to_parquet('data/df_write.parquet')
# # df_read_parquet = pd.read_parquet('data/df_write.parquet')

# %%
s_randn = pd.Series(np.random.randn(5), index = ['a', 'b', 'c', 'd', 'e'])
print(s_randn)
print(s_randn.index)
# Out:
# a   -0.087894
# b   -0.089348
# c   -0.996556
# d    0.258166
# e   -1.131219
# dtype: float64
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
print(pd.Series({'a': 1, 'v': 2, 'c': 'success'}))
# Out:
# a          1
# v          2
# c    success
# dtype: object

# %%
print(s_randn.iloc[0])
print(s_randn.iloc[:3])
print(s_randn.median())
print(s_randn[s_randn > s_randn.median()])
print(s_randn.iloc[[4, 3, 1]])
print('np.exp:', np.exp(s_randn))
# Out:
# -0.0878944178202146
# a   -0.087894
# b   -0.089348
# c   -0.996556
# dtype: float64
# -0.08934831286362294
# a   -0.087894
# d    0.258166
# dtype: float64
# e   -1.131219
# d    0.258166
# b   -0.089348
# dtype: float64
# np.exp: a    0.915858
# b    0.914527
# c    0.369148
# d    1.294554
# e    0.322640
# dtype: float64

# %%
print(s_randn.to_numpy())
print('s_randn:', s_randn)
print('s_randn.a is:', s_randn.a, s_randn['a'])
# Out:
# [-0.08789442 -0.08934831 -0.99655646  0.25816633 -1.1312186 ]
# s_randn: a   -0.087894
# b   -0.089348
# c   -0.996556
# d    0.258166
# e   -1.131219
# dtype: float64
# s_randn.a is: -0.0878944178202146 -0.0878944178202146

# %%
s_randn.e = 12
print(s_randn)
print(s_randn.get('f'))
# print(s_randn['f']) # 报错
# Out:
# a    -0.087894
# b    -0.089348
# c    -0.996556
# d     0.258166
# e    12.000000
# dtype: float64
# None

# %%
print(np.zeros((3,2)))
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
s_randn
# Out:
# a    -0.087894
# b    -0.089348
# c    -0.996556
# d     0.258166
# e    12.000000
# dtype: float64

# %%
dfa = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
dfa_new = dfa.assign(C = lambda x : x['A'] + x['B'], D = lambda x : x['A'] + x['C'])
print(dfa)
print(dfa_new)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A  B  C   D
# 0  1  4  5   6
# 1  2  5  7   9
# 2  3  6  9  12

# %%
print(dfa['A'])
print(dfa.loc[2])
print(dfa.iloc[1])
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64
# A    3
# B    6
# Name: 2, dtype: int64
# A    2
# B    5
# Name: 1, dtype: int64

# %%
ser1 = pd.Series([3, 2, 3], index=["a", "b", "c"])
ser2 = pd.Series([4, 3, 5], index=["b", "a", "c"])
print(np.remainder(ser1, ser2))
# Out:
# a    0
# b    2
# c    3
# dtype: int64

# %%
titanic_info_msg = pd.read_csv('data/titanic.csv')
print(titanic_info_msg.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  9 non-null      int64
#  1   Name         9 non-null      object
#  2   Survived     9 non-null      int64
#  3   Pclass       9 non-null      int64
#  4   Sex          9 non-null      object
#  5   Age          9 non-null      int64
#  6   SibSp        9 non-null      int64
#  7   Parch        9 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 708.0+ bytes
# None

# %%
basic_index = pd.date_range('1/1/2000', periods = 8)
basic_s = pd.Series(np.random.randn(5), index = ['a', 'b', 'c', 'd', 'e'])
basic_df = pd.DataFrame(np.random.randn(8, 3), index = basic_index, columns = ['A', 'B', 'C'])
basic_long_series = pd.Series(np.random.randn(1000))
print('basic_index:\n',basic_index)
print('basic_s:\n', basic_s)
print('basic_df:\n', basic_df)
print('basic_long_series:\n', basic_long_series.tail())
# Out:
# basic_index:
#  DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')
# basic_s:
#  a    0.742853
# b   -0.691152
# c   -0.404060
# d    1.593910
# e   -1.521632
# dtype: float64
# basic_df:
#                     A         B         C
# 2000-01-01  0.057305  0.755263 -0.018145
# 2000-01-02 -0.378235  0.703643  0.074024
# 2000-01-03 -0.603091  0.181260 -1.647980
# 2000-01-04 -0.330344  1.246773  0.703694
# 2000-01-05 -1.086875 -1.559097  0.424505
# 2000-01-06  0.653845  0.009806 -1.194682
# 2000-01-07 -0.016276 -0.365563 -0.791553
# 2000-01-08 -0.912262  0.707395 -0.393567
# basic_long_series:
#  995   -0.629036
# 996    1.885677
# 997   -0.263699
# 998    0.331605
# 999    1.241091
# dtype: float64

# %%
basic_df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
(1.394981 + 1.772517) / 3
# Out:
# 1.0558326666666666

# %%
df_prod = pd.Series([-1, 2, 3])
print(df_prod)
# 求各值的乘积
print(df_prod.prod())
print(df_prod.iloc[:1])
print(df_prod.loc[:2])
# Out:
# 0   -1
# 1    2
# 2    3
# dtype: int64
# -6
# 0   -1
# dtype: int64
# 0   -1
# 1    2
# 2    3
# dtype: int64

# %%
# melt 顶层 melt() 函数和相应的 DataFrame.melt() 有助于将 DataFrame 整理成一种格式，其中一个或多个列是标识符变量，而所有其他被视为测量变量的列则“解除透视”到行轴，只剩下两个非标识符列：“variable”和“value”。这些列的名称可以通过提供 var_name 和 value_name 参数进行自定义。
# Out:
#   city_and_code
# 0   Chicago, IL
